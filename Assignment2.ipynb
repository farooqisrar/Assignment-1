# %%
RollNo = [10, 20, 30, 40, 50, 60, 80]
print (len(RollNo))
# Out:
# 7

# %%
print(sum(RollNo))
# Out:
# 290

# %%
print(max(RollNo))
# Out:
# 80

# %%
a = [1,1,2,3,4,5,6,7,13,35,67,89]
for x in a:
    if x < 5: 
        print (x)
# Out:
# 1
# 1
# 2
# 3
# 4
