# %%
print( "Twinkle Twinkle, little Star,\n\tHow I wonder What you are!\n\t\tUp above the world so high,\n\t\tLike a diamond in the sky.\nTwinkle Twinkle, little Star,\n\tHow I wonder what you are")
# Out:
# Twinkle Twinkle, little Star,
# 	How I wonder What you are!
# 		Up above the world so high,
# 		Like a diamond in the sky.
# Twinkle Twinkle, little Star,
# 	How I wonder what you are

# %%
import sys
print("Python Version")
print(sys.version)
# Out:
# Python Version
# 3.13.1 (main, Apr 30 2025, 11:41:46) [Clang 20.0.0git (https:/github.com/llvm/llvm-project 1d810ece2b2c8fab7772049386

# %%
import datetime
now = datetime.datetime.now()
print("Current date and time:")
print(now.strftime("%Y-%m-%d%H:%M:%S"))
# Out:
# Current date and time:
# 2026-02-2621:07:06

# %%
import math
radius =float(input("Input the radius of the circle:"))
area = math.pi * radius**2
print(f"The area of the circle with radius {radius} is: {area}")
# Out:
# Input the radius of the circle: 1.1
# The area of the circle with radius 1.1 is: 3.8013271108436504

# %%
firstname = input("Input your first Name")
lastname = input("Input your last name")
print(f"Hello {firstname} {lastname}")
# Out:
# Input your first Name Syed farooq
# Input your last name israr
# Hello Syed farooq israr

# %%
Input1 = int(input("Input first value"))
Input2 = int(input("Input second value"))

print(f"the sum is:{Input1 + Input2}")
# Out:
# Input first value 20
# Input second value 20
# the sum is:40

# %%
sub1 = float(input("Enter marks for Subject 1: "))
sub2 = float(input("Enter marks for Subject 2: "))
sub3 = float(input("Enter marks for Subject 3: "))
sub4 = float(input("Enter marks for Subject 4: "))
sub5 = float(input("Enter marks for Subject 5: "))

total = sub1 + sub2 + sub3 + sub4 + sub5
percentage = (total / 500) * 100

if percentage >= 80:
    grade = "A+"
elif percentage >= 70:
    grade = "A"
elif percentage >= 60:
    grade = "B"
else:
    grade = "Fail"

print(f"Total Marks: {total}, Percentage: {percentage}%, Grade: {grade}")
# Out:
# Enter marks for Subject 1:  80
# Enter marks for Subject 2:  90
# Enter marks for Subject 3:  89
# Enter marks for Subject 4:  78
# Enter marks for Subject 5:  90
# Total Marks: 427.0, Percentage: 85.39999999999999%, Grade: A+
